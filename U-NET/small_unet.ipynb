# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import matplotlib.pyplot as plt
import numpy as np


def conv_block(inputs, filters, kernel_size=3):
    x= inputs
    for i in range(2):
        x= tf.keras.layers.Conv2D(filters, kernel_size, kernel_initializer="he_normal",
                                 padding="same")(x)
        x= tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(inputs, filters=32):
    f= conv_block(inputs, filters=filters) ##output for the concat
    p= tf.keras.layers.MaxPooling2D((2,2))(f)
    p= tf.keras.layers.Dropout(0.2)(p)
    return f, p


def encoder(inputs):
    filters=32
    f1, p1 = encoder_block(inputs, filters)
    f2, p2 = encoder_block(p1, filters*2)
    f3, p3 = encoder_block(p2, filters*4)
    f4, p4 = encoder_block(p3, filters*8)
    return p4, (f1, f2, f3, f4)


def bottleneck(inputs):
    bottle_neck = conv_block(inputs, 512)
    return bottle_neck


def decoder_block(inputs, conv_out, filters=256, kernel_size=3, strides=2):
    u= tf.keras.layers.Conv2DTranspose(filters, kernel_size, strides, padding="same")(inputs)
    cat= tf.keras.layers.concatenate([u, conv_out])
    cat= tf.keras.layers.Dropout(0.2)(cat)
    cat= conv_block(cat, filters, kernel_size)
    return cat


def decoder(inputs, convs, out_channels,filters=256,):
    f1, f2, f3, f4 = convs
    
    c6 = decoder_block(inputs, f4, filters)
    c7 = decoder_block(c6, f3, filters/2)
    c8= decoder_block(c7, f2, filters/4)
    c9= decoder_block(c8, f1, filters/8)
    
    outputs= tf.keras.layers.Conv2D(out_channels, 1, activation="softmax")(c9)
    return outputs

# %%
OUTPUT_CHANNELS=4
def unet():
    
    inputs= tf.keras.layers.Input(shape=(128, 128, 1))
    #inputs= tf.keras.layers.Lambda(lambda x: x/255)(inputs)
    encoder_output, convs = encoder(inputs)
    bottle_neck= bottleneck(encoder_output)
    outputs= decoder(bottle_neck, convs, OUTPUT_CHANNELS)
    model= tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

model= unet()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 16  160         ['input_4[0][0]']
#                                 )
#
#  activation_36 (Activation)     (None, 128, 128, 16  0           ['conv2d_38[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 16  2320        ['activation_36[0][0]']
#                                 )
#
#  activation_37 (Activation)     (None, 128, 128, 16  0           ['conv2d_39[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 16)  0           ['activation_37[0][0]']
#
#  dropout_16 (Dropout)           (None, 64, 64, 16)   0           ['max_pooling2d_8[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 32)   4640        ['dropout_16[0][0]']
#
#  activation_38 (Activation)     (None, 64, 64, 32)   0           ['conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_38[0][0]']
#
#  activation_39 (Activation)     (None, 64, 64, 32)   0           ['conv2d_41[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_39[0][0]']
#
#  dropout_17 (Dropout)           (None, 32, 32, 32)   0           ['max_pooling2d_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 64)   18496       ['dropout_17[0][0]']
#
#  activation_40 (Activation)     (None, 32, 32, 64)   0           ['conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_40[0][0]']
#
#  activation_41 (Activation)     (None, 32, 32, 64)   0           ['conv2d_43[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 64)  0           ['activation_41[0][0]']
#  )
#
#  dropout_18 (Dropout)           (None, 16, 16, 64)   0           ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 128)  73856       ['dropout_18[0][0]']
#
#  activation_42 (Activation)     (None, 16, 16, 128)  0           ['conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_42[0][0]']
#
#  activation_43 (Activation)     (None, 16, 16, 128)  0           ['conv2d_45[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 128)   0           ['activation_43[0][0]']
#  )
#
#  dropout_19 (Dropout)           (None, 8, 8, 128)    0           ['max_pooling2d_11[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 256)    295168      ['dropout_19[0][0]']
#
#  activation_44 (Activation)     (None, 8, 8, 256)    0           ['conv2d_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 256)    590080      ['activation_44[0][0]']
#
#  activation_45 (Activation)     (None, 8, 8, 256)    0           ['conv2d_47[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 16, 16, 128)  295040     ['activation_45[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'activation_43[0][0]']
#
#  dropout_20 (Dropout)           (None, 16, 16, 256)  0           ['concatenate_8[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_20[0][0]']
#
#  activation_46 (Activation)     (None, 16, 16, 128)  0           ['conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_46[0][0]']
#
#  activation_47 (Activation)     (None, 16, 16, 128)  0           ['conv2d_49[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_47[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'activation_41[0][0]']
#
#  dropout_21 (Dropout)           (None, 32, 32, 128)  0           ['concatenate_9[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_21[0][0]']
#
#  activation_48 (Activation)     (None, 32, 32, 64)   0           ['conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_48[0][0]']
#
#  activation_49 (Activation)     (None, 32, 32, 64)   0           ['conv2d_51[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 64, 64, 32)  18464       ['activation_49[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 64)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'activation_39[0][0]']
#
#  dropout_22 (Dropout)           (None, 64, 64, 64)   0           ['concatenate_10[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_22[0][0]']
#
#  activation_50 (Activation)     (None, 64, 64, 32)   0           ['conv2d_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_50[0][0]']
#
#  activation_51 (Activation)     (None, 64, 64, 32)   0           ['conv2d_53[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 128, 128, 16  4624       ['activation_51[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 32  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'activation_37[0][0]']
#
#  dropout_23 (Dropout)           (None, 128, 128, 32  0           ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_23[0][0]']
#                                 )
#
#  activation_52 (Activation)     (None, 128, 128, 16  0           ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 16  2320        ['activation_52[0][0]']
#                                 )
#
#  activation_53 (Activation)     (None, 128, 128, 16  0           ['conv2d_55[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 4)  68          ['activation_53[0][0]']
#
# ==================================================================================================
# Total params: 2,158,468
# Trainable params: 2,158,468
# Non-trainable params: 0
# __________________________________________________________________________________________________
