# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import matplotlib.pyplot as plt
import numpy as np


def conv_block(inputs, filters, kernel_size=3):
    x = inputs
    for i in range(2):
        x = tf.keras.layers.Conv2D(filters, kernel_size, kernel_initializer="he_normal",
                                   padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)  # Apply BatchNorm
        x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(inputs, filters=64):
    f = conv_block(inputs, filters=filters)  # output for the concat
    p = tf.keras.layers.MaxPooling2D((2, 2))(f)
    p = tf.keras.layers.Dropout(0.2)(p)
    return f, p


def encoder(inputs):
    filters = 64
    f1, p1 = encoder_block(inputs, filters)
    f2, p2 = encoder_block(p1, filters * 2)
    f3, p3 = encoder_block(p2, filters * 4)
    f4, p4 = encoder_block(p3, filters * 8)
    return p4, (f1, f2, f3, f4)


def bottleneck(inputs):
    bottle_neck = conv_block(inputs, 1024)
    return bottle_neck


def decoder_block(inputs, conv_out, filters=512, kernel_size=3, strides=2):
    u = tf.keras.layers.Conv2DTranspose(filters, kernel_size, strides, padding="same")(inputs)
    cat = tf.keras.layers.concatenate([u, conv_out])
    cat = tf.keras.layers.Dropout(0.2)(cat)
    cat = conv_block(cat, filters, kernel_size)
    return cat


def decoder(inputs, convs, out_channels, filters=512):
    f1, f2, f3, f4 = convs

    c6 = decoder_block(inputs, f4, filters)
    c7 = decoder_block(c6, f3, filters / 2)
    c8 = decoder_block(c7, f2, filters / 4)
    c9 = decoder_block(c8, f1, filters / 8)

    outputs = tf.keras.layers.Conv2D(out_channels, 1, activation="softmax")(c9)
    return outputs

# %%
OUTPUT_CHANNELS=4
def unet():
    
    inputs= tf.keras.layers.Input(shape=(128, 128, 1))
    #inputs= tf.keras.layers.Lambda(lambda x: x/255)(inputs)
    encoder_output, convs = encoder(inputs)
    bottle_neck= bottleneck(encoder_output)
    outputs= decoder(bottle_neck, convs, OUTPUT_CHANNELS)
    model= tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

model= unet()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 64  640         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 64  36928       ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_19[0][0]']
#
#  dropout_8 (Dropout)            (None, 64, 64, 64)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 128)  73856       ['dropout_8[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_21[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_21[0][0]']
#
#  dropout_9 (Dropout)            (None, 32, 32, 128)  0           ['max_pooling2d_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 256)  295168      ['dropout_9[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_23[0][0]']
#
#  dropout_10 (Dropout)           (None, 16, 16, 256)  0           ['max_pooling2d_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 512)  1180160     ['dropout_10[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 512)   0           ['activation_25[0][0]']
#
#  dropout_11 (Dropout)           (None, 8, 8, 512)    0           ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 1024)   4719616     ['dropout_11[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 1024)   9438208     ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 512)  4719104    ['activation_27[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'activation_25[0][0]']
#
#  dropout_12 (Dropout)           (None, 16, 16, 1024  0           ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 512)  4719104     ['dropout_12[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 256)  1179904    ['activation_29[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_23[0][0]']
#
#  dropout_13 (Dropout)           (None, 32, 32, 512)  0           ['concatenate_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 256)  1179904     ['dropout_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 128)  295040     ['activation_31[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'activation_21[0][0]']
#
#  dropout_14 (Dropout)           (None, 64, 64, 256)  0           ['concatenate_6[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 128)  295040      ['dropout_14[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 128)  512        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 64  73792      ['activation_33[0][0]']
#  spose)                         )
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  dropout_15 (Dropout)           (None, 128, 128, 12  0           ['concatenate_7[0][0]']
#                                 8)
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 64  73792       ['dropout_15[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 64  36928       ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 4)  260         ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 34,535,940
# Trainable params: 34,524,164
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
