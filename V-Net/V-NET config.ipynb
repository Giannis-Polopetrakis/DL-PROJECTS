# %%
conv
bn
relu
------------input 
conv 
bn
relu
------------down 1 
conv
bn
add
relu
------------ block 1
conv
bn
relu
------------ down
conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
add
relu
-------------block 2
conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
add
relu
------------block 3
conv
bn
relu
------------ down
conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
add
relu
------------block 4 6x6x6x256
conv 
bn
relu
cat

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
add
relu
-----------------up1
conv 
bn
relu
cat

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
relu

conv
bn
add
relu
----------up2
conv 
bn
relu
cat

conv
bn
relu

conv
bn
add
relu
---------up3
conv
bn
relu
cat

conv
bn
add
relu
-------up4
conv 
bn
softmax
------
softmax
