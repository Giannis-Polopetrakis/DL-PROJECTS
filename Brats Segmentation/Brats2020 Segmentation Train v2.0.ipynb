# %%
import os
import numpy as np
from Brats2020_Segmentation_Data_Generator import imageLoader
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random
from keras import backend as K
from matplotlib import pyplot as plt
import random

# %%
def conv_block(inputs, filters, kernel_size=3):
    x = inputs
    for i in range(2):
        x = tf.keras.layers.Conv3D(filters, kernel_size, kernel_initializer="he_normal",
                                   padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)  # Apply BatchNorm
        x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(inputs, filters=16):
    f = conv_block(inputs, filters=filters)  # output for the concat
    p = tf.keras.layers.MaxPooling3D((2, 2, 2))(f)
    p = tf.keras.layers.Dropout(0.2)(p)
    return f, p


def encoder(inputs):
    filters = 16
    f1, p1 = encoder_block(inputs, filters)
    f2, p2 = encoder_block(p1, filters * 2)
    f3, p3 = encoder_block(p2, filters * 4)
    f4, p4 = encoder_block(p3, filters * 8)
    return p4, (f1, f2, f3, f4)


def bottleneck(inputs):
    bottle_neck = conv_block(inputs, 256)
    return bottle_neck


def decoder_block(inputs, conv_out, filters=128, kernel_size=3, strides=(2, 2, 2)):
    u = tf.keras.layers.Conv3DTranspose(filters, kernel_size, strides, padding="same")(inputs)
    cat = tf.keras.layers.concatenate([u, conv_out])
    cat = tf.keras.layers.Dropout(0.2)(cat)
    cat = conv_block(cat, filters, kernel_size)
    return cat


def decoder(inputs, convs, out_channels, filters=128):
    f1, f2, f3, f4 = convs

    c6 = decoder_block(inputs, f4, filters)
    c7 = decoder_block(c6, f3, filters // 2)
    c8 = decoder_block(c7, f2, filters // 4)
    c9 = decoder_block(c8, f1, filters // 8)

    outputs = tf.keras.layers.Conv3D(out_channels, 1, activation="softmax")(c9)
    return outputs

# %%
OUTPUT_CHANNELS=4
def unet():
    
    inputs= tf.keras.layers.Input(shape=(128, 128, 128, 3))
    #inputs= tf.keras.layers.Lambda(lambda x: x/255)(inputs)
    encoder_output, convs = encoder(inputs)
    bottle_neck= bottleneck(encoder_output)
    outputs= decoder(bottle_neck, convs, OUTPUT_CHANNELS)
    model= tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

model= unet()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d_38 (Conv3D)             (None, 128, 128, 12  1312        ['input_3[0][0]']
#                                 8, 16)
#
#  batch_normalization_36 (BatchN  (None, 128, 128, 12  64         ['conv3d_38[0][0]']
#  ormalization)                  8, 16)
#
#  activation_36 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_36[0][0]']
#                                 8, 16)
#
#  conv3d_39 (Conv3D)             (None, 128, 128, 12  6928        ['activation_36[0][0]']
#                                 8, 16)
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 12  64         ['conv3d_39[0][0]']
#  ormalization)                  8, 16)
#
#  activation_37 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_37[0][0]']
#                                 8, 16)
#
#  max_pooling3d_8 (MaxPooling3D)  (None, 64, 64, 64,   0          ['activation_37[0][0]']
#                                 16)
#
#  dropout_16 (Dropout)           (None, 64, 64, 64,   0           ['max_pooling3d_8[0][0]']
#                                 16)
#
#  conv3d_40 (Conv3D)             (None, 64, 64, 64,   13856       ['dropout_16[0][0]']
#                                 32)
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 64,   128        ['conv3d_40[0][0]']
#  ormalization)                  32)
#
#  activation_38 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_38[0][0]']
#                                 32)
#
#  conv3d_41 (Conv3D)             (None, 64, 64, 64,   27680       ['activation_38[0][0]']
#                                 32)
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 64,   128        ['conv3d_41[0][0]']
#  ormalization)                  32)
#
#  activation_39 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_39[0][0]']
#                                 32)
#
#  max_pooling3d_9 (MaxPooling3D)  (None, 32, 32, 32,   0          ['activation_39[0][0]']
#                                 32)
#
#  dropout_17 (Dropout)           (None, 32, 32, 32,   0           ['max_pooling3d_9[0][0]']
#                                 32)
#
#  conv3d_42 (Conv3D)             (None, 32, 32, 32,   55360       ['dropout_17[0][0]']
#                                 64)
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 32,   256        ['conv3d_42[0][0]']
#  ormalization)                  64)
#
#  activation_40 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_40[0][0]']
#                                 64)
#
#  conv3d_43 (Conv3D)             (None, 32, 32, 32,   110656      ['activation_40[0][0]']
#                                 64)
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 32,   256        ['conv3d_43[0][0]']
#  ormalization)                  64)
#
#  activation_41 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_41[0][0]']
#                                 64)
#
#  max_pooling3d_10 (MaxPooling3D  (None, 16, 16, 16,   0          ['activation_41[0][0]']
#  )                              64)
#
#  dropout_18 (Dropout)           (None, 16, 16, 16,   0           ['max_pooling3d_10[0][0]']
#                                 64)
#
#  conv3d_44 (Conv3D)             (None, 16, 16, 16,   221312      ['dropout_18[0][0]']
#                                 128)
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 16,   512        ['conv3d_44[0][0]']
#  ormalization)                  128)
#
#  activation_42 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_42[0][0]']
#                                 128)
#
#  conv3d_45 (Conv3D)             (None, 16, 16, 16,   442496      ['activation_42[0][0]']
#                                 128)
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 16,   512        ['conv3d_45[0][0]']
#  ormalization)                  128)
#
#  activation_43 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_43[0][0]']
#                                 128)
#
#  max_pooling3d_11 (MaxPooling3D  (None, 8, 8, 8, 128  0          ['activation_43[0][0]']
#  )                              )
#
#  dropout_19 (Dropout)           (None, 8, 8, 8, 128  0           ['max_pooling3d_11[0][0]']
#                                 )
#
#  conv3d_46 (Conv3D)             (None, 8, 8, 8, 256  884992      ['dropout_19[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 8, 256  1024       ['conv3d_46[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 8, 8, 8, 256  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  conv3d_47 (Conv3D)             (None, 8, 8, 8, 256  1769728     ['activation_44[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 8, 256  1024       ['conv3d_47[0][0]']
#  ormalization)                  )
#
#  activation_45 (Activation)     (None, 8, 8, 8, 256  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  conv3d_transpose_8 (Conv3DTran  (None, 16, 16, 16,   884864     ['activation_45[0][0]']
#  spose)                         128)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_8[0][0]',
#                                 256)                              'activation_43[0][0]']
#
#  dropout_20 (Dropout)           (None, 16, 16, 16,   0           ['concatenate_8[0][0]']
#                                 256)
#
#  conv3d_48 (Conv3D)             (None, 16, 16, 16,   884864      ['dropout_20[0][0]']
#                                 128)
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 16,   512        ['conv3d_48[0][0]']
#  ormalization)                  128)
#
#  activation_46 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_46[0][0]']
#                                 128)
#
#  conv3d_49 (Conv3D)             (None, 16, 16, 16,   442496      ['activation_46[0][0]']
#                                 128)
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 16,   512        ['conv3d_49[0][0]']
#  ormalization)                  128)
#
#  activation_47 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_47[0][0]']
#                                 128)
#
#  conv3d_transpose_9 (Conv3DTran  (None, 32, 32, 32,   221248     ['activation_47[0][0]']
#  spose)                         64)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_9[0][0]',
#                                 128)                              'activation_41[0][0]']
#
#  dropout_21 (Dropout)           (None, 32, 32, 32,   0           ['concatenate_9[0][0]']
#                                 128)
#
#  conv3d_50 (Conv3D)             (None, 32, 32, 32,   221248      ['dropout_21[0][0]']
#                                 64)
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 32,   256        ['conv3d_50[0][0]']
#  ormalization)                  64)
#
#  activation_48 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_48[0][0]']
#                                 64)
#
#  conv3d_51 (Conv3D)             (None, 32, 32, 32,   110656      ['activation_48[0][0]']
#                                 64)
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 32,   256        ['conv3d_51[0][0]']
#  ormalization)                  64)
#
#  activation_49 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_49[0][0]']
#                                 64)
#
#  conv3d_transpose_10 (Conv3DTra  (None, 64, 64, 64,   55328      ['activation_49[0][0]']
#  nspose)                        32)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 64,   0           ['conv3d_transpose_10[0][0]',
#                                 64)                               'activation_39[0][0]']
#
#  dropout_22 (Dropout)           (None, 64, 64, 64,   0           ['concatenate_10[0][0]']
#                                 64)
#
#  conv3d_52 (Conv3D)             (None, 64, 64, 64,   55328       ['dropout_22[0][0]']
#                                 32)
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 64,   128        ['conv3d_52[0][0]']
#  ormalization)                  32)
#
#  activation_50 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_50[0][0]']
#                                 32)
#
#  conv3d_53 (Conv3D)             (None, 64, 64, 64,   27680       ['activation_50[0][0]']
#                                 32)
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 64,   128        ['conv3d_53[0][0]']
#  ormalization)                  32)
#
#  activation_51 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_51[0][0]']
#                                 32)
#
#  conv3d_transpose_11 (Conv3DTra  (None, 128, 128, 12  13840      ['activation_51[0][0]']
#  nspose)                        8, 16)
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 12  0           ['conv3d_transpose_11[0][0]',
#                                 8, 32)                            'activation_37[0][0]']
#
#  dropout_23 (Dropout)           (None, 128, 128, 12  0           ['concatenate_11[0][0]']
#                                 8, 32)
#
#  conv3d_54 (Conv3D)             (None, 128, 128, 12  13840       ['dropout_23[0][0]']
#                                 8, 16)
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 12  64         ['conv3d_54[0][0]']
#  ormalization)                  8, 16)
#
#  activation_52 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_52[0][0]']
#                                 8, 16)
#
#  conv3d_55 (Conv3D)             (None, 128, 128, 12  6928        ['activation_52[0][0]']
#                                 8, 16)
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 12  64         ['conv3d_55[0][0]']
#  ormalization)                  8, 16)
#
#  activation_53 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_53[0][0]']
#                                 8, 16)
#
#  conv3d_56 (Conv3D)             (None, 128, 128, 12  68          ['activation_53[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 6,478,596
# Trainable params: 6,475,652
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 128, 128, 128, 3)
# (None, 128, 128, 128, 4)

# %%
train_img_dir = "BraTS2020_TrainingData/input_data_128/train/images/"
train_mask_dir = "BraTS2020_TrainingData/input_data_128/train/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
train_img_dir = "BraTS2020_TrainingData/input_data_128/train/images/"
train_mask_dir = "BraTS2020_TrainingData/input_data_128/train/masks/"

val_img_dir = "BraTS2020_TrainingData/input_data_128/val/images/"
val_mask_dir = "BraTS2020_TrainingData/input_data_128/val/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 1

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
img.shape
# Out:
# (1, 128, 128, 128, 3)

# %%
msk.shape
# Out:
# (1, 128, 128, 128, 4)

# %%
def dice_coefficient(y_true, y_pred):
    smooth = 1.0
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    
    intersection = K.sum(flat_y_true * flat_y_pred)
    union = K.sum(flat_y_true) + K.sum(flat_y_pred)
    
    dice_score = (2.0 * intersection + smooth) / (union + smooth)
    
    return dice_score

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones_like(y_true)
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2,3))
    den = num + alpha*K.sum(p0*g1,(0,1,2,3)) + beta*K.sum(p1*g0,(0,1,2,3))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
metrics = ['accuracy', dice_coefficient]

# %%
LR = 0.0001
optim = keras.optimizers.Adam(LR)

# %%
model.compile(optimizer = optim, loss=tversky_loss, metrics=metrics)

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# %%
history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# Epoch 1/40
# 258/258 [==============================] - 208s 799ms/step - loss: 3.2190 - accuracy: 0.5311 - dice_coefficient: 0.4242 - val_loss: 3.0875 - val_accuracy: 0.6732 - val_dice_coefficient: 0.5017
# Epoch 2/40
# 258/258 [==============================] - 208s 805ms/step - loss: 2.9457 - accuracy: 0.8410 - dice_coefficient: 0.5397 - val_loss: 3.0249 - val_accuracy: 0.7497 - val_dice_coefficient: 0.5204
# Epoch 3/40
# 258/258 [==============================] - 207s 802ms/step - loss: 2.7556 - accuracy: 0.9274 - dice_coefficient: 0.6202 - val_loss: 2.8623 - val_accuracy: 0.8260 - val_dice_coefficient: 0.6003
# Epoch 4/40
# 258/258 [==============================] - 206s 799ms/step - loss: 2.5682 - accuracy: 0.9457 - dice_coefficient: 0.6968 - val_loss: 2.7116 - val_accuracy: 0.8403 - val_dice_coefficient: 0.6718
# Epoch 5/40
# 258/258 [==============================] - 206s 798ms/step - loss: 2.3790 - accuracy: 0.9536 - dice_coefficient: 0.7655 - val_loss: 2.5337 - val_accuracy: 0.8650 - val_dice_coefficient: 0.7358
# Epoch 6/40
# 258/258 [==============================] - 206s 798ms/step - loss: 2.1844 - accuracy: 0.9591 - dice_coefficient: 0.8232 - val_loss: 2.2680 - val_accuracy: 0.9134 - val_dice_coefficient: 0.8149
# Epoch 7/40
# 258/258 [==============================] - 206s 799ms/step - loss: 1.9844 - accuracy: 0.9639 - dice_coefficient: 0.8725 - val_loss: 2.0542 - val_accuracy: 0.9361 - val_dice_coefficient: 0.8734
# Epoch 8/40
# 258/258 [==============================] - 205s 793ms/step - loss: 1.7701 - accuracy: 0.9705 - dice_coefficient: 0.9131 - val_loss: 1.8892 - val_accuracy: 0.9358 - val_dice_coefficient: 0.9009
# Epoch 9/40
# 258/258 [==============================] - 206s 798ms/step - loss: 1.5783 - accuracy: 0.9742 - dice_coefficient: 0.9397 - val_loss: 1.7592 - val_accuracy: 0.9571 - val_dice_coefficient: 0.9321
# Epoch 10/40
# 258/258 [==============================] - 209s 809ms/step - loss: 1.4156 - accuracy: 0.9773 - dice_coefficient: 0.9556 - val_loss: 1.6936 - val_accuracy: 0.9678 - val_dice_coefficient: 0.9513
# Epoch 11/40
# 258/258 [==============================] - 209s 812ms/step - loss: 1.2999 - accuracy: 0.9788 - dice_coefficient: 0.9645 - val_loss: 1.5312 - val_accuracy: 0.9683 - val_dice_coefficient: 0.9576
# Epoch 12/40
# 258/258 [==============================] - 208s 806ms/step - loss: 1.2169 - accuracy: 0.9793 - dice_coefficient: 0.9693 - val_loss: 1.5316 - val_accuracy: 0.9693 - val_dice_coefficient: 0.9619
# Epoch 13/40
# 258/258 [==============================] - 205s 796ms/step - loss: 1.1338 - accuracy: 0.9807 - dice_coefficient: 0.9734 - val_loss: 1.5254 - val_accuracy: 0.9711 - val_dice_coefficient: 0.9657
# Epoch 14/40
# 258/258 [==============================] - 204s 793ms/step - loss: 1.0770 - accuracy: 0.9815 - dice_coefficient: 0.9760 - val_loss: 1.4975 - val_accuracy: 0.9734 - val_dice_coefficient: 0.9693
# Epoch 15/40
# 258/258 [==============================] - 204s 790ms/step - loss: 1.0342 - accuracy: 0.9821 - dice_coefficient: 0.9779 - val_loss: 1.5161 - val_accuracy: 0.9718 - val_dice_coefficient: 0.9682
# Epoch 16/40
# 258/258 [==============================] - 207s 801ms/step - loss: 0.9864 - accuracy: 0.9827 - dice_coefficient: 0.9794 - val_loss: 1.4747 - val_accuracy: 0.9751 - val_dice_coefficient: 0.9730
# Epoch 17/40
# 258/258 [==============================] - 214s 830ms/step - loss: 0.9809 - accuracy: 0.9823 - dice_coefficient: 0.9796 - val_loss: 1.3727 - val_accuracy: 0.9742 - val_dice_coefficient: 0.9724
# Epoch 18/40
# 258/258 [==============================] - 207s 801ms/step - loss: 0.9384 - accuracy: 0.9832 - dice_coefficient: 0.9809 - val_loss: 1.3325 - val_accuracy: 0.9720 - val_dice_coefficient: 0.9703
# Epoch 19/40
# 258/258 [==============================] - 207s 802ms/step - loss: 0.9156 - accuracy: 0.9834 - dice_coefficient: 0.9815 - val_loss: 1.2356 - val_accuracy: 0.9722 - val_dice_coefficient: 0.9706
# Epoch 20/40
# 258/258 [==============================] - 208s 805ms/step - loss: 0.9043 - accuracy: 0.9835 - dice_coefficient: 0.9818 - val_loss: 1.4453 - val_accuracy: 0.9747 - val_dice_coefficient: 0.9735
# Epoch 21/40
# 258/258 [==============================] - 207s 801ms/step - loss: 0.8780 - accuracy: 0.9841 - dice_coefficient: 0.9826 - val_loss: 1.3069 - val_accuracy: 0.9758 - val_dice_coefficient: 0.9749
# Epoch 22/40
# 258/258 [==============================] - 206s 799ms/step - loss: 0.8534 - accuracy: 0.9844 - dice_coefficient: 0.9831 - val_loss: 1.2394 - val_accuracy: 0.9735 - val_dice_coefficient: 0.9725
# Epoch 23/40
# 258/258 [==============================] - 205s 796ms/step - loss: 0.8481 - accuracy: 0.9844 - dice_coefficient: 0.9832 - val_loss: 1.2431 - val_accuracy: 0.9763 - val_dice_coefficient: 0.9755
# Epoch 24/40
# 258/258 [==============================] - 206s 800ms/step - loss: 0.8242 - accuracy: 0.9848 - dice_coefficient: 0.9837 - val_loss: 1.1864 - val_accuracy: 0.9754 - val_dice_coefficient: 0.9746
# Epoch 25/40
# 258/258 [==============================] - 204s 792ms/step - loss: 0.8153 - accuracy: 0.9850 - dice_coefficient: 0.9840 - val_loss: 1.3356 - val_accuracy: 0.9764 - val_dice_coefficient: 0.9756
# Epoch 26/40
# 258/258 [==============================] - 206s 797ms/step - loss: 0.8064 - accuracy: 0.9851 - dice_coefficient: 0.9842 - val_loss: 1.2639 - val_accuracy: 0.9763 - val_dice_coefficient: 0.9757
# Epoch 27/40
# 258/258 [==============================] - 206s 800ms/step - loss: 0.7843 - accuracy: 0.9856 - dice_coefficient: 0.9847 - val_loss: 1.3049 - val_accuracy: 0.9759 - val_dice_coefficient: 0.9753
# Epoch 28/40
# 258/258 [==============================] - 210s 815ms/step - loss: 0.7751 - accuracy: 0.9856 - dice_coefficient: 0.9848 - val_loss: 1.3358 - val_accuracy: 0.9746 - val_dice_coefficient: 0.9740
# Epoch 29/40
# 258/258 [==============================] - 207s 804ms/step - loss: 0.7744 - accuracy: 0.9857 - dice_coefficient: 0.9850 - val_loss: 1.2517 - val_accuracy: 0.9730 - val_dice_coefficient: 0.9725
# Epoch 30/40
# 258/258 [==============================] - 204s 790ms/step - loss: 0.7679 - accuracy: 0.9859 - dice_coefficient: 0.9852 - val_loss: 1.2314 - val_accuracy: 0.9728 - val_dice_coefficient: 0.9723
# Epoch 31/40
# 258/258 [==============================] - 207s 801ms/step - loss: 0.7561 - accuracy: 0.9858 - dice_coefficient: 0.9852 - val_loss: 1.2638 - val_accuracy: 0.9759 - val_dice_coefficient: 0.9754
# Epoch 32/40
# 258/258 [==============================] - 207s 802ms/step - loss: 0.7442 - accuracy: 0.9860 - dice_coefficient: 0.9855 - val_loss: 1.3222 - val_accuracy: 0.9726 - val_dice_coefficient: 0.9717
# Epoch 33/40
# 258/258 [==============================] - 206s 798ms/step - loss: 0.7278 - accuracy: 0.9864 - dice_coefficient: 0.9859 - val_loss: 1.3112 - val_accuracy: 0.9765 - val_dice_coefficient: 0.9761
# Epoch 34/40
# 258/258 [==============================] - 206s 799ms/step - loss: 0.7278 - accuracy: 0.9864 - dice_coefficient: 0.9859 - val_loss: 1.2588 - val_accuracy: 0.9749 - val_dice_coefficient: 0.9745
# Epoch 35/40
# 258/258 [==============================] - 207s 802ms/step - loss: 0.7192 - accuracy: 0.9866 - dice_coefficient: 0.9862 - val_loss: 1.2939 - val_accuracy: 0.9753 - val_dice_coefficient: 0.9749
# Epoch 36/40
# 258/258 [==============================] - 205s 796ms/step - loss: 0.7183 - accuracy: 0.9865 - dice_coefficient: 0.9861 - val_loss: 1.2554 - val_accuracy: 0.9760 - val_dice_coefficient: 0.9758
# Epoch 37/40
# 258/258 [==============================] - 206s 801ms/step - loss: 0.7472 - accuracy: 0.9861 - dice_coefficient: 0.9857 - val_loss: 1.1978 - val_accuracy: 0.9770 - val_dice_coefficient: 0.9767
# Epoch 38/40
# 258/258 [==============================] - 208s 806ms/step - loss: 0.7143 - accuracy: 0.9867 - dice_coefficient: 0.9863 - val_loss: 1.2403 - val_accuracy: 0.9764 - val_dice_coefficient: 0.9761
# Epoch 39/40
# 258/258 [==============================] - 207s 803ms/step - loss: 0.6959 - accuracy: 0.9871 - dice_coefficient: 0.9867 - val_loss: 1.2590 - val_accuracy: 0.9700 - val_dice_coefficient: 0.9697
# Epoch 40/40
# 258/258 [==============================] - 206s 797ms/step - loss: 0.7024 - accuracy: 0.9869 - dice_coefficient: 0.9865 - val_loss: 1.2763 - val_accuracy: 0.9759 - val_dice_coefficient: 0.9756

# %%
model.save("brats_3d_40_epochs_v2.hdf5")

# %%
from keras.models import load_model

# %%
model = load_model('brats_3d_40_epochs_v2.hdf5', 
                      custom_objects={'tversky_loss': tversky_loss,
                                      'dice_coefficient':dice_coefficient})

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['dice_coefficient']
val_acc = history.history['val_dice_coefficient']

plt.plot(epochs, acc, 'y', label='Training dice_coefficient')
plt.plot(epochs, val_acc, 'r', label='Validation dice_coefficient')
plt.title('Training and validation dice_coefficient')
plt.xlabel('Epochs')
plt.ylabel('dice_coefficient')
plt.legend()
plt.show()

# %%
from keras.metrics import MeanIoU

batch_size=1 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)


test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 1s 504ms/step
# Mean IoU = 0.58680165

# %%
img_num = 88

test_img = np.load("BraTS2020_TrainingData/input_data_128/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("BraTS2020_TrainingData/input_data_128/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
n_slice=random.randint(0, test_prediction_argmax.shape[2])
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()

# %%
#### The model has been trained for very little epochs. make sure to re-train it
