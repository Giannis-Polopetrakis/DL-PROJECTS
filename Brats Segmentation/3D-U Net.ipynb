# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import numpy as np


def conv_block(inputs, filters, kernel_size=3):
    x = inputs
    for i in range(2):
        x = tf.keras.layers.Conv3D(filters, kernel_size, kernel_initializer="he_normal",
                                   padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)  # Apply BatchNorm
        x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(inputs, filters=64):
    f = conv_block(inputs, filters=filters)  # output for the concat
    p = tf.keras.layers.MaxPooling3D((2, 2, 2))(f)
    p = tf.keras.layers.Dropout(0.2)(p)
    return f, p


def encoder(inputs):
    filters = 64
    f1, p1 = encoder_block(inputs, filters)
    f2, p2 = encoder_block(p1, filters * 2)
    f3, p3 = encoder_block(p2, filters * 4)
    f4, p4 = encoder_block(p3, filters * 8)
    return p4, (f1, f2, f3, f4)


def bottleneck(inputs):
    bottle_neck = conv_block(inputs, 1024)
    return bottle_neck


def decoder_block(inputs, conv_out, filters=512, kernel_size=3, strides=(2, 2, 2)):
    u = tf.keras.layers.Conv3DTranspose(filters, kernel_size, strides, padding="same")(inputs)
    cat = tf.keras.layers.concatenate([u, conv_out])
    cat = tf.keras.layers.Dropout(0.2)(cat)
    cat = conv_block(cat, filters, kernel_size)
    return cat


def decoder(inputs, convs, out_channels, filters=512):
    f1, f2, f3, f4 = convs

    c6 = decoder_block(inputs, f4, filters)
    c7 = decoder_block(c6, f3, filters // 2)
    c8 = decoder_block(c7, f2, filters // 4)
    c9 = decoder_block(c8, f1, filters // 8)

    outputs = tf.keras.layers.Conv3D(out_channels, 1, activation="softmax")(c9)
    return outputs

# %%
OUTPUT_CHANNELS=4
def unet():
    
    inputs= tf.keras.layers.Input(shape=(128, 128, 128, 3))
    #inputs= tf.keras.layers.Lambda(lambda x: x/255)(inputs)
    encoder_output, convs = encoder(inputs)
    bottle_neck= bottleneck(encoder_output)
    outputs= decoder(bottle_neck, convs, OUTPUT_CHANNELS)
    model= tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

model= unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 3)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  5248        ['input_1[0][0]']
#                                 8, 64)
#
#  batch_normalization (BatchNorm  (None, 128, 128, 12  256        ['conv3d[0][0]']
#  alization)                     8, 64)
#
#  activation (Activation)        (None, 128, 128, 12  0           ['batch_normalization[0][0]']
#                                 8, 64)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  110656      ['activation[0][0]']
#                                 8, 64)
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 12  256        ['conv3d_1[0][0]']
#  rmalization)                   8, 64)
#
#  activation_1 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_1[0][0]']
#                                 8, 64)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['activation_1[0][0]']
#                                 64)
#
#  dropout (Dropout)              (None, 64, 64, 64,   0           ['max_pooling3d[0][0]']
#                                 64)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   221312      ['dropout[0][0]']
#                                 128)
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64,   512        ['conv3d_2[0][0]']
#  rmalization)                   128)
#
#  activation_2 (Activation)      (None, 64, 64, 64,   0           ['batch_normalization_2[0][0]']
#                                 128)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   442496      ['activation_2[0][0]']
#                                 128)
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64,   512        ['conv3d_3[0][0]']
#  rmalization)                   128)
#
#  activation_3 (Activation)      (None, 64, 64, 64,   0           ['batch_normalization_3[0][0]']
#                                 128)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['activation_3[0][0]']
#                                 128)
#
#  dropout_1 (Dropout)            (None, 32, 32, 32,   0           ['max_pooling3d_1[0][0]']
#                                 128)
#
#  conv3d_4 (Conv3D)              (None, 32, 32, 32,   884992      ['dropout_1[0][0]']
#                                 256)
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 32,   1024       ['conv3d_4[0][0]']
#  rmalization)                   256)
#
#  activation_4 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_4[0][0]']
#                                 256)
#
#  conv3d_5 (Conv3D)              (None, 32, 32, 32,   1769728     ['activation_4[0][0]']
#                                 256)
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 32,   1024       ['conv3d_5[0][0]']
#  rmalization)                   256)
#
#  activation_5 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_5[0][0]']
#                                 256)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['activation_5[0][0]']
#                                 256)
#
#  dropout_2 (Dropout)            (None, 16, 16, 16,   0           ['max_pooling3d_2[0][0]']
#                                 256)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   3539456     ['dropout_2[0][0]']
#                                 512)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 16,   2048       ['conv3d_6[0][0]']
#  rmalization)                   512)
#
#  activation_6 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_6[0][0]']
#                                 512)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   7078400     ['activation_6[0][0]']
#                                 512)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 16,   2048       ['conv3d_7[0][0]']
#  rmalization)                   512)
#
#  activation_7 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_7[0][0]']
#                                 512)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 512  0          ['activation_7[0][0]']
#                                 )
#
#  dropout_3 (Dropout)            (None, 8, 8, 8, 512  0           ['max_pooling3d_3[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 102  14156800    ['dropout_3[0][0]']
#                                 4)
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 8, 102  4096       ['conv3d_8[0][0]']
#  rmalization)                   4)
#
#  activation_8 (Activation)      (None, 8, 8, 8, 102  0           ['batch_normalization_8[0][0]']
#                                 4)
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 102  28312576    ['activation_8[0][0]']
#                                 4)
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 8, 102  4096       ['conv3d_9[0][0]']
#  rmalization)                   4)
#
#  activation_9 (Activation)      (None, 8, 8, 8, 102  0           ['batch_normalization_9[0][0]']
#                                 4)
#
#  conv3d_transpose (Conv3DTransp  (None, 16, 16, 16,   14156288   ['activation_9[0][0]']
#  ose)                           512)
#
#  concatenate (Concatenate)      (None, 16, 16, 16,   0           ['conv3d_transpose[0][0]',
#                                 1024)                             'activation_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 16,   0           ['concatenate[0][0]']
#                                 1024)
#
#  conv3d_10 (Conv3D)             (None, 16, 16, 16,   14156288    ['dropout_4[0][0]']
#                                 512)
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 16,   2048       ['conv3d_10[0][0]']
#  ormalization)                  512)
#
#  activation_10 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_10[0][0]']
#                                 512)
#
#  conv3d_11 (Conv3D)             (None, 16, 16, 16,   7078400     ['activation_10[0][0]']
#                                 512)
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 16,   2048       ['conv3d_11[0][0]']
#  ormalization)                  512)
#
#  activation_11 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_11[0][0]']
#                                 512)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 32, 32, 32,   3539200    ['activation_11[0][0]']
#  spose)                         256)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_1[0][0]',
#                                 512)                              'activation_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 32,   0           ['concatenate_1[0][0]']
#                                 512)
#
#  conv3d_12 (Conv3D)             (None, 32, 32, 32,   3539200     ['dropout_5[0][0]']
#                                 256)
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 32,   1024       ['conv3d_12[0][0]']
#  ormalization)                  256)
#
#  activation_12 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_12[0][0]']
#                                 256)
#
#  conv3d_13 (Conv3D)             (None, 32, 32, 32,   1769728     ['activation_12[0][0]']
#                                 256)
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 32,   1024       ['conv3d_13[0][0]']
#  ormalization)                  256)
#
#  activation_13 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_13[0][0]']
#                                 256)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 64, 64, 64,   884864     ['activation_13[0][0]']
#  spose)                         128)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_2[0][0]',
#                                 256)                              'activation_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64,   0           ['concatenate_2[0][0]']
#                                 256)
#
#  conv3d_14 (Conv3D)             (None, 64, 64, 64,   884864      ['dropout_6[0][0]']
#                                 128)
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64,   512        ['conv3d_14[0][0]']
#  ormalization)                  128)
#
#  activation_14 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_14[0][0]']
#                                 128)
#
#  conv3d_15 (Conv3D)             (None, 64, 64, 64,   442496      ['activation_14[0][0]']
#                                 128)
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64,   512        ['conv3d_15[0][0]']
#  ormalization)                  128)
#
#  activation_15 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_15[0][0]']
#                                 128)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 128, 128, 12  221248     ['activation_15[0][0]']
#  spose)                         8, 64)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_3[0][0]',
#                                 8, 128)                           'activation_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 12  0           ['concatenate_3[0][0]']
#                                 8, 128)
#
#  conv3d_16 (Conv3D)             (None, 128, 128, 12  221248      ['dropout_7[0][0]']
#                                 8, 64)
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 12  256        ['conv3d_16[0][0]']
#  ormalization)                  8, 64)
#
#  activation_16 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_16[0][0]']
#                                 8, 64)
#
#  conv3d_17 (Conv3D)             (None, 128, 128, 12  110656      ['activation_16[0][0]']
#                                 8, 64)
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 12  256        ['conv3d_17[0][0]']
#  ormalization)                  8, 64)
#
#  activation_17 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_17[0][0]']
#                                 8, 64)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  260         ['activation_17[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 103,549,956
# Trainable params: 103,538,180
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
